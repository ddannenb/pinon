# %%
# %load_ext autoreload
# %autoreload 2

# %aimport pinon

import pinon as pn
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
sas = pn.SaScraper()
sas.get_earnings_estimates('V')
# Out:
# Here
# ...
